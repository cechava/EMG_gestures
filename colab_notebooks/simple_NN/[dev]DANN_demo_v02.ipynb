# %%
#Run cell to mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install package to have access to custom functions
# %pip install /content/drive/MyDrive/EMG_gestures/ --use-feature=in-tree-build
# Out:
# Processing ./drive/MyDrive/EMG_gestures
# Building wheels for collected packages: EMG-gestures
#   Building wheel for EMG-gestures (setup.py) ... done
#   Created wheel for EMG-gestures: filename=EMG_gestures-0.1.0-py3-none-any.whl size=43972 sha256=5b2bfd80e6ea88be8627049c58e7d4855d173ce164a80f1f890bcb914b5205db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zz0vyvbv/wheels/a2/b7/61/2147fa082a9e51bef5dcc38dd3f0898fe0554d62203c0e383e
# Successfully built EMG-gestures
# Installing collected packages: EMG-gestures
# Successfully installed EMG-gestures-0.1.0

# %%
# %matplotlib inline

from itertools import groupby
import numpy as np
import pandas as pd
import scipy
import scipy.signal

#to visualize 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as patches
#style params for figures
sns.set(font_scale = 2)
plt.style.use('seaborn-white')
plt.rc("axes", labelweight="bold")


#to load files
import os
import h5py

from sklearn.datasets import make_blobs
from tensorflow.keras.utils import to_categorical

from EMG_gestures.utils import *
from EMG_gestures.models import DANN
from EMG_gestures.analysis import DANN_test

# %%
#make fake data and visualiz
X1, y1 = make_blobs(500, centers=[[0, 0], [0, 1]], cluster_std=0.2)
X2, y2 = make_blobs(500, centers=[[1, -1], [1, 0]], cluster_std=0.2)

fig, ax = plt.subplots(figsize=(8,7))
ax.scatter(X1[:,0], X1[:,1], c=y1, cmap='coolwarm', alpha=0.4)
ax.scatter(X2[:,0], X2[:,1], c=y2, cmap='cool', alpha=0.4)
ax.set_ylabel('Dimension 2')
ax.set_xlabel('Dimension 1')
ax.set_xticks(())
ax.set_yticks(())
# Out:
# []

# %%
epochs = 30
batch_size = 10
score_list = ['accuracy']

X_source, Y_source, scaler = prepare_data_for_log_reg(X1,y1, np.arange(X1.shape[0]), [], train = True)
X_target, Y_target, scaler = prepare_data_for_log_reg(X2,y2, np.arange(X2.shape[0]), [], scaler = scaler)

#stack
X_all = np.vstack((X_source,X_target))
Y_all = np.vstack((Y_source,Y_target))

# create domain labels
Y_all_domain = np.hstack((np.ones(X1.shape[0],)*0,np.ones(X2.shape[0],)*1))#source_label
Y_all_domain = to_categorical(Y_all_domain)

# %%
n_features, n_outputs = X_source.shape[1], Y_source.shape[1]

#define and compile model
input_shape = (n_features,)
dann_model = DANN(input_shape, n_outputs, fe_layers = 1, dp_layers = 1, activation = 'tanh')
dann_model.compile(loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method GradientReversalLayer.call of <EMG_gestures.models.GradientReversalLayer object at 0x7f3fa02eed50>> and will run it as-is.
# Cause: code mixing tabs and spaces for indentation is not allowed
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method GradientReversalLayer.call of <EMG_gestures.models.GradientReversalLayer object at 0x7f3fa02eed50>> and will run it as-is.
# Cause: code mixing tabs and spaces for indentation is not allowed
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
np.random.seed(10)
dann_model.train_label_pred(X_source, Y_source, epochs=epochs, batch_size=batch_size, verbose=0)

# %%
#label class accuracy
source_label_score = get_scores(X_source, Y_source, dann_model.predict_label, score_list)
target_label_score = get_scores(X_target, Y_target, dann_model.predict_label, score_list)

#domain class accuracy
domain_score = get_scores(X_all, Y_all, dann_model.predict_domain, score_list)

print('After training on source labels ONLY:\n')
print('Source label accuracy: %.02f'%(source_label_score))
print('Target label accuracy: %.02f'%(target_label_score))
print('Domain accuracy: %.02f'%(domain_score))
# Out:
# After training on source labels ONLY:
#
# Source label accuracy: 0.99
# Target label accuracy: 0.50
# Domain accuracy: 0.26

# %%
#Visualizing decision boundary for labels
xx, yy = make_meshgrid(X_all[:,0], X_all[:,1])

fig, ax = plt.subplots(figsize=(8,7))
title = ('Class Label Decision Boundary ')
plot_contours(ax, dann_model.predict_label, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X_source[:,0], X_source[:,1], c=np.argmax(Y_source,1), cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.scatter(X_target[:,0], X_target[:,1], c=np.argmax(Y_target,1), cmap=plt.cm.cool, s=20, edgecolors='k')
ax.set_ylabel('Dimension 2')
ax.set_xlabel('Dimension 1')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
# Domain adaptation with domain labels
np.random.seed(1)
dann_model.train_domain_adapt(X_source, Y_source, X_target,\
                              epochs = epochs*3, batch_size = batch_size, verbose = 0)

# %%
#label class accuracy
source_label_score = get_scores(X_source, Y_source, dann_model.predict_label, score_list)
target_label_score = get_scores(X_target, Y_target, dann_model.predict_label, score_list)

#domain class accuracy
domain_score = get_scores(X_all, Y_all, dann_model.predict_domain, score_list)

print('After domain adapttion:\n')
print('Source label accuracy: %.02f'%(source_label_score))
print('Target label accuracy: %.02f'%(target_label_score))
print('Domain accuracy: %.02f'%(domain_score))
# Out:
# After domain adapttion:
#
# Source label accuracy: 0.96
# Target label accuracy: 0.96
# Domain accuracy: 0.04

# %%
#Visualizing decision boundary for labels
xx, yy = make_meshgrid(X_all[:,0], X_all[:,1])

fig, ax = plt.subplots(figsize=(8,7))
title = ('Class Label Decision Boundary ')
plot_contours(ax, dann_model.predict_label, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X_source[:,0], X_source[:,1], c=np.argmax(Y_source,1), cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.scatter(X_target[:,0], X_target[:,1], c=np.argmax(Y_target,1), cmap=plt.cm.cool, s=20, edgecolors='k')
ax.set_ylabel('Dimension 2')
ax.set_xlabel('Dimension 1')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
# with labels revealed

#define and compile model
input_shape = (n_features,)
dann_model = DANN(input_shape, n_outputs, fe_layers = 1, dp_layers = 1, activation = 'tanh')
dann_model.compile(loss='categorical_crossentropy')

# %%
np.random.seed(1)
dann_model.train_domain_and_labels(X_source, Y_source, X_target, Y_target,\
                                   epochs=epochs*2, batch_size=batch_size, verbose=0)

# %%
#label class accuracy
source_label_score = get_scores(X_source, Y_source, dann_model.predict_label, score_list)
target_label_score = get_scores(X_target, Y_target, dann_model.predict_label, score_list)

#domain class accuracy
domain_score = get_scores(X_all, Y_all, dann_model.predict_domain, score_list)

print('After training with ALL labels revealed:\n')
print('Source label accuracy: %.02f'%(source_label_score))
print('Target label accuracy: %.02f'%(target_label_score))
print('Domain accuracy: %.02f'%(domain_score))
# Out:
# After training with ALL labels revealed:
#
# Source label accuracy: 0.96
# Target label accuracy: 0.96
# Domain accuracy: 0.04

# %%
#Visualizing decision boundary for labels
xx, yy = make_meshgrid(X_all[:,0], X_all[:,1])

fig, ax = plt.subplots(figsize=(8,7))
title = ('Class Label Decision Boundary ')
plot_contours(ax, dann_model.predict_label, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X_source[:,0], X_source[:,1], c=np.argmax(Y_source,1), cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.scatter(X_target[:,0], X_target[:,1], c=np.argmax(Y_target,1), cmap=plt.cm.cool, s=20, edgecolors='k')
ax.set_ylabel('Dimension 2')
ax.set_xlabel('Dimension 1')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
#repeat

epochs = 30
batch_size = 10
score_list = ['accuracy']
n_splits = 3
nreps = 10


np.random.seed(42)
results_df = []
for rep in range(nreps):
    print('Rep %d'%(rep+1))
    print('---- True Data---')
    
    sub_df = DANN_test(X1, y1, X2, y2, score_list, n_splits,\
                           epochs, batch_size)
    sub_df['Rep'] = rep+1
    sub_df['Shuffled'] = False
    
    print('---- Permuted Data---')
    results_df.append(sub_df)
    sub_df = DANN_test(X1, y1, X2, y2, score_list, n_splits,\
                           epochs, batch_size, permute = True)
    sub_df['Rep'] = rep+1
    sub_df['Shuffled'] = True
    results_df.append(sub_df)
    
results_df = pd.concat(results_df, axis = 0)

#save to file
results_fn = './DANN_test_multiple_runs_results.h5'
results_df.to_hdf(results_fn, key='results_df', mode='w')
# Out:
# Rep 1
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 2
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 3
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 4
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 5
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 6
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 7
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 8
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 9
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Rep 10
# ---- True Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# ---- Permuted Data---
# Split Count: 1
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 2
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed
# Split Count: 3
# Training on Source Labels
# Adapting to target Domain
# Training with all labels revealed

# %%
results_folder = '/content/drive/MyDrive/EMG_gestures/results_data/DANN_test'
results_fn = 'DANN_test_multiple_runs_results.h5'
results_df.to_hdf(os.path.join(results_folder,results_fn), key='results_df', mode='w')

# %%
#load results
results_folder = '/content/drive/MyDrive/EMG_gestures/results_data/DANN_test'
results_fn = 'DANN_test_multiple_runs_results.h5'
results_df = pd.read_hdf(os.path.join(results_folder,results_fn), 'results_df')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-1c5505d8c359> in <module>()
#       2 results_folder = '/content/drive/MyDrive/EMG_gestures/results_data/DANN_test'
#       3 results_fn = 'DANN_test_multiple_runs_results.h5'
# ----> 4 results_df = pd.read_hdf(os.path.join(results_folder,results_fn), 'results_df')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     421             iterator=iterator,
#     422             chunksize=chunksize,
# --> 423             auto_close=auto_close,
#     424         )
#     425     except (ValueError, TypeError, KeyError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     865         )
#     866
# --> 867         return it.get_result()
#     868
#     869     def select_as_coordinates(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in get_result(self, coordinates)
#    1919
#    1920         # directly return the result
# -> 1921         results = self.func(self.start, self.stop, where)
#    1922         self.close()
#    1923         return results
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in func(_start, _stop, _where)
#     849         # function to call on iteration
#     850         def func(_start, _stop, _where):
# --> 851             return s.read(start=_start, stop=_stop, where=_where, columns=columns)
#     852
#     853         # create the iterator
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in read(self, where, columns, start, stop)
#    3159
#    3160             blk_items = self.read_index(f"block{i}_items")
# -> 3161             values = self.read_array(f"block{i}_values", start=_start, stop=_stop)
#    3162
#    3163             columns = items[items.get_indexer(blk_items)]
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in read_array(self, key, start, stop)
#    2816
#    2817         if isinstance(node, tables.VLArray):
# -> 2818             ret = node[0][start:stop]
#    2819         else:
#    2820             dtype = _ensure_decoded(getattr(attrs, "value_type", None))
#
# /usr/local/lib/python3.7/dist-packages/tables/vlarray.py in __getitem__(self, key)
#     679                 key += self.nrows
#     680             (start, stop, step) = self._process_range(key, key + 1, 1)
# --> 681             return self.read(start, stop, step)[0]
#     682         elif isinstance(key, slice):
#     683             start, stop, step = self._process_range(
#
# /usr/local/lib/python3.7/dist-packages/tables/vlarray.py in read(self, start, stop, step)
#     819             listarr = []
#     820         else:
# --> 821             listarr = self._read_array(start, stop, step)
#     822
#     823         atom = self.atom
#
# tables/hdf5extension.pyx in tables.hdf5extension.VLArray._read_array()
#
# ValueError: cannot set WRITEABLE flag to True of this array

# %%
# Out:
# /content

# %%
#visualize results

#average over folds
# keep_types = ['Source_Train','Source_Test','Naive_Target_Train','Naive_Target_Test',\
#               'Adapt_Source_Train','Adapt_Source_Test']
keep_types = ['Source_Test','Naive_Target_Test','Adapt_Target_Test']
plot_df = results_df.loc[results_df.Type.isin(keep_types)]
plot_df = plot_df.groupby(['Type','Shuffled','Rep'])\
.mean()\
.drop(columns = ['Fold'])\
.reset_index()

shuffle_df = plot_df.loc[plot_df.Shuffled == True]
true_df = plot_df.loc[plot_df.Shuffled == False]

# Get confidence interval for shuffled data results
null_ci = np.zeros((len(keep_types),2))

for j,t in enumerate(keep_types):
    null_df = shuffle_df.loc[shuffle_df.Type == t]
    null_ci[j,:] = sns.utils.ci(sns.algorithms.bootstrap(null_df['accuracy_score'].values))


#make plot
g = sns.catplot(data = true_df, x= 'Type', y = 'accuracy_score',\
            order = keep_types, kind = 'box', aspect = 2)

# #Label axes and subpots, mark chance confidence interval
for i,ax in enumerate(g.axes[0]):
    ax.set_xlabel('')
    ax.set_ylim([.45,1])
    ax.set_xticklabels(keep_types,horizontalalignment = 'center')
    ax.set_ylabel('Accuracy')
    for j,t in enumerate(keep_types):
        ax.add_patch(patches.Rectangle((j-0.35, null_ci[j,0]), 0.7, (null_ci[j,1]-null_ci[j,0]),\
                                             linewidth=0, fill=True, color='k', alpha=0.2))

sns.despine(fig=g.fig, bottom = True)

# %%
null_ci
# Out:
# array([[0.48966667, 0.51166667],
#        [0.49      , 0.51166667]])
