# %%
#Run cell to mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import necessary packages

#our workhorses
import numpy as np
import pandas as pd
import scipy

#to visualize
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
#style params for figures
sns.set(font_scale = 2)
plt.style.use('seaborn-white')
plt.rc("axes", labelweight="bold")
from IPython.display import display, HTML

#to load files
import os
import sys
import h5py

#append repo folder to search path
sys.path.append('/content/drive/MyDrive/limb-position-EMG/limb-position-EMG/')
from utils import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ff2afd5023a5> in <module>()
#      23 #append repo folder to search path
#      24 sys.path.append('/content/drive/MyDrive/limb-position-EMG/limb-position-EMG/')
# ---> 25 from utils import *
#      26
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#define where the data files are located
data_folder = '/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/'
results_folder = '/content/drive/MyDrive/limb-position-EMG-Repo/results_data/single_subject_training/log_reg_mv/'

nsubjects = 36


# User-defined parameters
lo_freq = 20 #lower bound of bandpass filter
hi_freq = 450 #upper bound of bandpass filter

win_size = 100 #define window size over which to compute time-domain features
step = win_size #keeping this parameter in case we want to re-run later with some overlap

nreps = 10
exclude = [0,7]#labels to exclude

#for RNN training
verbose = 0
epochs = 40
batch_size = 2

for subject_id in range(1,nsubjects+1):
    
    subject_folder = os.path.join(data_folder,'%02d'%(subject_id))
    print('=======================')
    print(subject_folder)

    # Process data and get features 
    #get features across segments and corresponding info
    feature_matrix_sub, target_labels_sub, window_tstamps_sub, \
    block_labels_sub, series_labels_sub = get_subject_data_for_classification(subject_folder, lo_freq, hi_freq, \
                                                                    win_size, step)
    np.random.seed(1)#for reproducibility
    results_df = []#initialize empty array for dataframes
    for rep in range(nreps):
        print('Subject %d|Rep %d'%(subject_id, rep+1))

        print('True Data')
        train_f1, test_f1 = within_subject_log_reg_performance(feature_matrix_sub, target_labels_sub, series_labels_sub, exclude,\
                                                                            verbose = 0, epochs = epochs, batch_size = batch_size,mv = True, permute = False)
        results_df.append(pd.DataFrame({'F1_score':train_f1,\
                            'Fold':np.arange(train_f1.size)+1,\
                            'Rep':[rep+1 for x in range(train_f1.size)],\
                            'Type':['Train' for x in range(train_f1.size)],\
                            'Shuffled':[False for x in range(train_f1.size)],\
                            'Subject':[subject_id for x in range(train_f1.size)],\
                            }))
        results_df.append(pd.DataFrame({'F1_score':test_f1,\
                            'Fold':np.arange(test_f1.size)+1,\
                            'Rep':[rep+1 for x in range(test_f1.size)],\
                            'Type':['Test' for x in range(test_f1.size)],\
                            'Shuffled':[False for x in range(test_f1.size)],\
                            'Subject':[subject_id for x in range(test_f1.size)],\
                            }))
        
        print('Permuted Data')
        train_f1_perm, test_f1_perm = within_subject_log_reg_performance(feature_matrix_sub, target_labels_sub, series_labels_sub, exclude,\
                                                                            verbose = 0, epochs = epochs, batch_size = batch_size, mv = True, permute = True)
        results_df.append(pd.DataFrame({'F1_score':train_f1_perm,\
                            'Fold':np.arange(train_f1_perm.size)+1,\
                            'Rep':[rep+1 for x in range(train_f1_perm.size)],\
                            'Type':['Train' for x in range(train_f1_perm.size)],\
                            'Shuffled':[True for x in range(train_f1_perm.size)],\
                            'Subject':[subject_id for x in range(train_f1_perm.size)],\
                            }))
        results_df.append(pd.DataFrame({'F1_score':test_f1_perm,\
                            'Fold':np.arange(test_f1_perm.size)+1,\
                            'Rep':[rep+1 for x in range(test_f1_perm.size)],\
                            'Type':['Test' for x in range(test_f1_perm.size)],\
                            'Shuffled':[True for x in range(test_f1_perm.size)],\
                            'Subject':[subject_id for x in range(test_f1_perm.size)],\
                            }))
    results_df = pd.concat(results_df, axis = 0)
    #save results to file
    results_fn = 'subject_%02d_within_subject_results.h5'%(subject_id)
    results_df.to_hdf(os.path.join(results_folder,results_fn), key='results_df', mode='w')
# Out:
# Streaming output truncated to the last 5000 lines.
# Evaluate Model
# Subject 4|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 4|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Subject 5|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 5|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Subject 6|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 6|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Subject 7|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 7|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Subject 8|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 8|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Subject 9|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 9|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Subject 10|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 10|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Subject 11|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 11|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Subject 12|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 12|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Subject 13|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 13|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Subject 14|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 14|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Subject 15|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 15|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Subject 16|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 16|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Subject 17|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 17|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Subject 18|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 18|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Subject 19|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 19|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Subject 20|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 20|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Subject 21|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 21|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Subject 22|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 22|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Subject 23|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 23|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Subject 24|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 24|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Subject 25|Rep 1
# True Data
# Split Count: 1
# Training Model
# ...
# Subject 30|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 30|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Subject 31|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 31|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Subject 32|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 32|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Subject 33|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 33|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Subject 34|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 34|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Subject 35|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 35|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Subject 36|Rep 1
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 2
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 3
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 4
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 5
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 6
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 7
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 8
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 9
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Subject 36|Rep 10
# True Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model
# Permuted Data
# Split Count: 1
# Training Model
# Evaluate Model
# Split Count: 2
# Training Model
# Evaluate Model

# %%
n_splits = np.unique(series_labels).size
X = feature_matrix_sub.copy()
Y = target_labels_sub.copy()
exclude =[0,7]

#for RNN training
verbose = 0
epochs = 40
batch_size = 2
# Out:
# Split Count: 1
# Split Count: 2

# %%
# Out:
# Training Model

# %%
# Out:
# (593, 7)
