# %%
#Run cell to mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import necessary packages

#our workhorses
import numpy as np
import pandas as pd
import scipy

#to visualize
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
#style params for figures
sns.set(font_scale = 2)
plt.style.use('seaborn-white')
plt.rc("axes", labelweight="bold")
from IPython.display import display, HTML

#to load files
import os
import sys
import h5py

#append repo folder to search path
sys.path.append('/content/drive/MyDrive/limb-position-EMG-Repo/')
from utils import *

# %%
#define where the data files are located
data_folder = '/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/'
results_folder = '/content/drive/MyDrive/limb-position-EMG-Repo/results_data/single_subject_training/log_reg_mv/'

nsubjects = 36


# User-defined parameters
lo_freq = 20 #lower bound of bandpass filter
hi_freq = 450 #upper bound of bandpass filter

win_size = 100 #define window size over which to compute time-domain features
step = win_size #keeping this parameter in case we want to re-run later with some overlap


#for RNN training
epochs = 40
batch_size = 2


nreps = 10
exclude = [0,7]#labels to exclude

#src_subject_id = 1
for src_subject_id in range(1,nsubjects+1):

    results_df = log_reg_xsubject_test(data_folder, src_subject_id, nsubjects, nreps, lo_freq, hi_freq, win_size, step, exclude, \
                            epochs = epochs, batch_size = batch_size, mv = True, permute = False)

    results_df['Shuffled'] = False

    perm_results_df = log_reg_xsubject_test(data_folder, src_subject_id, nsubjects, nreps, lo_freq, hi_freq, win_size, step, exclude, \
                            epochs = epochs, batch_size = batch_size, mv = True, permute = True)

    perm_results_df['Shuffled'] = True

    #concatenate

    results_df = pd.concat([results_df, perm_results_df]).reset_index(drop = True)
    results_df['Train_Subject'] = src_subject_id

    #save results to file
    results_fn = 'subject_%02d_across_subject_results.h5'%(src_subject_id)
    results_df.to_hdf(os.path.join(results_folder,results_fn), key='results_df', mode='w')
# Out:
# Streaming output truncated to the last 5000 lines.
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 3
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 4
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 5
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 6
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 7
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 8
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 9
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 33|Rep 10
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# =======================
# /content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Subject 34|Rep 1
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 2
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 3
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 4
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 5
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 6
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/36
# Evaluate Model
# Subject 34|Rep 7
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# ...
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Subject 36|Rep 6
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Subject 36|Rep 7
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Subject 36|Rep 8
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Subject 36|Rep 9
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model
# Subject 36|Rep 10
# Training Model
# Evaluate Model on Trained Data
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/01
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/03
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/04
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/05
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/06
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/07
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/08
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/09
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/10
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/11
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/12
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/13
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/14
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/15
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/16
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/17
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/18
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/19
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/20
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/21
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/22
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/23
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/24
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/25
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/26
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/27
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/28
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/29
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/30
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/31
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/32
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/33
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/34
# Evaluate Model
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/35
# Evaluate Model

# %%
# Out:
# Target Subject :/content/drive/MyDrive/limb-position-EMG-Repo/EMG_data/02
# Evaluate Model

# %%
results_df.groupby(['Type','Shuffled']).mean()
# Out:
#                 F1_score  Rep  Test_Subject  Train_Subject
# Type  Shuffled
# Test  False     0.597290  5.5          19.0            1.0
#       True      0.140748  5.5          19.0            1.0
# Train False     0.901293  5.5           1.0            1.0
#       True      0.232926  5.5           1.0            1.0
